# %%
    import pandas as pd
    import seaborn as sns
    import matplotlib.pyplot as plt

# %%
data = pd.read_csv("Salary_Data2.csv")

# %%
data.shape
# Out:
# (6704, 6)

# %%
data.isnull().sum()
# Out:
# Age                    2
# Gender                 2
# Education Level        3
# Job Title              2
# Years of Experience    3
# Salary                 5
# dtype: int64

# %%
data.drop(columns = ["Gender","Job Title","Education Level"],inplace = True)

# %%
data.head(3)
# Out:
#     Age  Years of Experience    Salary
# 0  32.0                  5.0   90000.0
# 1  28.0                  3.0   65000.0
# 2  45.0                 15.0  150000.0

# %%
data.isnull().sum()
# Out:
# Age                    2
# Years of Experience    3
# Salary                 5
# dtype: int64

# %%
sns.pairplot(data=data)
plt.show
# Out:
# C:\ProgramData\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
sns.heatmap(data=data.corr(),annot =True)
# Out:
# <Axes: >

# %%
x = data.iloc[:,:-1]
x
# Out:
#        Age  Years of Experience
# 0     32.0                  5.0
# 1     28.0                  3.0
# 2     45.0                 15.0
# 3     36.0                  7.0
# 4     52.0                 20.0
# ...    ...                  ...
# 6699  49.0                 20.0
# 6700  32.0                  3.0
# 6701  30.0                  4.0
# 6702  46.0                 14.0
# 6703  26.0                  1.0
#
# [6704 rows x 2 columns]
