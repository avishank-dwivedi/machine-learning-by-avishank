# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
dataset = pd.read_csv("Salary_Data2.csv")

# %%
dataset.head(3)
# Out:
#     Age  Gender Education Level          Job Title  Years of Experience  \
# 0  32.0    Male      Bachelor's  Software Engineer                  5.0
# 1  28.0  Female        Master's       Data Analyst                  3.0
# 2  45.0    Male             PhD     Senior Manager                 15.0
#
#      Salary
# 0   90000.0
# 1   65000.0
# 2  150000.0

# %%
dataset.drop(columns=["Gender","Education Level","Job Title"],inplace =True)

# %%
dataset.shape
# Out:
# (6704, 3)

# %%
dataset.isnull().sum()
# Out:
# Age                    2
# Years of Experience    3
# Salary                 5
# dtype: int64

# %%
dataset["Age"].fillna(dataset["Age"].mean(),inplace=True)

# %%
dataset.head(3)
# Out:
#     Age  Years of Experience    Salary
# 0  32.0                  5.0   90000.0
# 1  28.0                  3.0   65000.0
# 2  45.0                 15.0  150000.0

# %%
dataset["Salary"].fillna(dataset["Salary"].mean(),inplace=True)

# %%
dataset["Years of Experience"].fillna(dataset["Years of Experience"].mean(),inplace=True)

# %%
dataset.isnull().sum()
# Out:
# Age                    0
# Years of Experience    0
# Salary                 0
# dtype: int64

# %%
sns.pairplot(data=dataset)
plt.show()
# Out:
# C:\ProgramData\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
sns.heatmap(data=dataset.corr(),annot =True)
plt.show()

# %%
x = dataset.iloc[:,:-1]
y = dataset["Salary"]

# %%
from sklearn.model_selection import train_test_split

# %%
x_train , x_test , y_train , y_test =  train_test_split(x ,y,test_size = 0.2 , random_state = 42)

# %%
from sklearn.linear_model import LinearRegression

# %%
lr = LinearRegression()

# %%
lr.fit(x_train , y_train)
# Out:
# LinearRegression()

# %%
lr.score(x_test,y_test)*100
# Out:
# 65.96019406488094

# %%
# y = m1*1 ,m2*2 + c

# %%
lr.coef_
# Out:
# array([-1788.21658218,  9163.69362624])

# %%
lr.intercept_
# Out:
# 101429.21353317279

# %%
x.columns
# Out:
# Index(['Age', 'Years of Experience'], dtype='object')

# %%
# y_pred = -1788.21658218*Age + 9163.69362624*Years of Experience+101429.21353317279

# %%
lr.predict(x_test)
# Out:
# array([198646.07939804, 113939.39874904,  80638.4466931 , ...,
#        123103.09237527, 156626.65514656, 222560.72711239])
